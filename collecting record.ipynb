# %% [markdown]
# ## collecting  data (collecting voice recording)

# %%
import sounddevice as sd 
import soundfile as sf 
import numpy as np
s=16000

# %%
s=16000
d=3
a=17
while(True):
    a=a+1
    b=str(a)
    q=input("open first lamp: ")
    if q== "o":
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait() 
        filename='E:\\recoder\\open first lamp\\'+b+'.wav'
        sf.write(filename,mydata,s)
    q=input("stop first lamp: ")
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait() 
        filename='E:\\recoder\\stop first lamp\\'+b+'.wav'
        sf.write(filename,mydata,s)
    q=input("open kitchen lamp: ")    
    if q== "o":
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait() 
        filename='E:\\recoder\\open kitchen lamp\\'+b+'.wav'
        sf.write(filename,mydata,s)  
    q=input("stop kitchen lamp: ")    
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait() 
        filename='E:\\recoder\\stop kitchen lamp\\'+b+'.wav'
        sf.write(filename,mydata,s) 
    q=input("open lamp bedroom: ")    
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait() 
        filename='E:\\recoder\\open lamp bedroom\\'+b+'.wav'
        sf.write(filename,mydata,s)  
    q=input("stop lamp bedroom: ")  
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait() 
        filename='E:\\recoder\\stop lamp bedroom\\'+b+'.wav'
        sf.write(filename,mydata,s)
    q=input("open the fan: ")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait() 
        filename='E:\\recoder\\open the fan\\'+b+'.wav'
        sf.write(filename,mydata,s)
    q=input("stop the fan: ")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\stop the fan\\'+b+'.wav'
        sf.write(filename,mydata,s)   
    q=input("  :شغل الضوء الاول ")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\شغل الضوء الاول\\'+b+'.wav'
        sf.write(filename,mydata,s)   
    q=input("  :اطفئ الضوء الاول")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\اطفئ الضوء الاول\\'+b+'.wav'
        sf.write(filename,mydata,s) 
    q=input("  :شغل ضوء المطبخ")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\شغل ضوء المطبخ\\'+b+'.wav'
        sf.write(filename,mydata,s)  
    q=input("  اطفئ ضوء المطبخ")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\اطفئ ضوء المطبخ\\'+b+'.wav'
        sf.write(filename,mydata,s) 
    q=input("  شغل المروحة")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\شغل المروحة\\'+b+'.wav'
        sf.write(filename,mydata,s)         
    q=input("اطفئ المروحة")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\اطفئ المروحة\\'+b+'.wav'
        sf.write(filename,mydata,s) 
    q=input("شغل ضوء غرفة النوم")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\شغل ضوء غرفة النوم\\'+b+'.wav'
        sf.write(filename,mydata,s)        
    q=input("اطفئ ضوء غرفة النوم")         
    if q== "o" :
        print("start")
        mydata=sd.rec(int(s*d),samplerate=s,channels=1,blocking=True)
        print("end")
        sd.wait()
        filename='E:\\recoder\\اطفئ ضوء غرفة النوم\\'+b+'.wav'
        sf.write(filename,mydata,s) 
        w=input('continue:  ')
        if w== 'o' :
            continue
        elif w== 'stop' :
            break
